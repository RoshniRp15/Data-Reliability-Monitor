# %% [markdown]
# # 🧹 Data Reliability Monitor — Demo Notebook
# This notebook demonstrates how the **DataReliabilityMonitor** detects:
# - Missing values
# - Duplicate rows
# - Outliers (IQR method)
#
# A clean and simple example for beginners + portfolio projects.

# %%
import pandas as pd
from src.data_checks import DataReliabilityMonitor

# %% [markdown]
# ## Load Sample Dataset
# Using a small sample dataset for demo.

# %%
sample_data = {
    'age': [25, 30, 29, None, 120],
    'salary': [40000, 50000, 48000, 50000, None],
    'score': [80, 85, 90, 95, 500]
}

df = pd.DataFrame(sample_data)
df

# %% [markdown]
# ## Run Data Quality Checks

# %%
monitor = DataReliabilityMonitor(df)
report = monitor.summary_report()
report
